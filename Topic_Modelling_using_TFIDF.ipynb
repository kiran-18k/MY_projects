# %% [markdown]
# <a href="https://colab.research.google.com/github/kiran-18k/MY_projects/blob/main/Topic_Modelling_using_TFIDF.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd '/content/drive/My Drive/OKR/Jishnu/amazon-ecomm-data/'
# Out:
# Mounted at /content/drive
# /content/drive/.shortcut-targets-by-id/1xZV7vb_-26-R9MiXmwecnzCcvAb8KBpR/OKR/Jishnu/amazon-ecomm-data

# %%
import os
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import math
import nltk

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df_reviews = pd.read_csv('beacon_ratings_reviews.csv',low_memory=False)
df_reviews.head()
# Out:
#    Unnamed: 0  retailerid retailername retailersku             upc  \
# 0           0           1   Amazon.com  B004EDWMBO  792850024007.0
# 1           1           1   Amazon.com  B011EVP32S   44600314464.0
# 2           2           1   Amazon.com  B014P0K2A8   44600315164.0
# 3           3           1   Amazon.com  B001DJDNM4   21888201327.0
# 4           4           1   Amazon.com  B01LTIAYM0   12587789186.0
#
#       modelNumber                                              title  \
# 0    792850009165  Burt's Bees Essential Gift Set, 5 Travel Size ...
# 1      H&PC-88028  Clorox Zero Splash Bleach Packs - Laundry Pods...
# 2    044600315164  Clorox ToiletWand Disinfecting Refills, Rainfo...
# 3           20132  Rainbow Light Counter Attack with Vitamin C an...
# 4  10012587789183  GLAD ForceFlexPlus XL X-Large Kitchen Drawstri...
#
#            Brand                         Category              SubCategory  \
# 0    Burt's Bees  Body Washes, Soaps & Treatments    Body Care Sets & Kits
# 1         Clorox                 Laundry Supplies           Laundry Bleach
# 2         Clorox               Toilet Accessories  Toilet Cleaning Systems
# 3  Rainbow Light                  Single Vitamins        Vitamin C-Complex
# 4           Glad       Trash, Recycling & Compost               Trash Bags
#
#    ...  WeekEnding  reviewDate        reviewId reviewStars  isVerified  \
# 0  ...  2020-02-08  2020-02-07   RGAK8O1J1LDO1         5.0         yes
# 1  ...  2020-02-08  2020-02-06  R190J6U8OYS150         4.0         yes
# 2  ...  2020-02-08  2020-02-05  R18K959KFRU58B         5.0         yes
# 3  ...  2020-02-08  2020-02-07  R36AFDSQ9IMA0S         5.0         yes
# 4  ...  2021-04-17  2021-04-15  R2EHYZBEID00FP         1.0         yes
#
#   hasResponse                                         reviewText  \
# 0          no                             Great Christmas gIft
# 1          no   Laundry. Easy to use. Convenience.Please keep...
# 2          no                           Love it. So easy to use
# 3          no   I was sick and had a friend recommend this to...
# 4          no                   Bags were weak and tore easily
#
#                            reviewTitle  \
# 0                        She loved it
# 1  " Its ""BLEACH"" ; Not ""Candy"". "
# 2                               Fresh
# 3                  Excellent Product!
# 4                        Bad Purchase
#
#                                           reviewsURL       reviewer
# 0  https://www.amazon.com/gp/customer-reviews/RGA...            gio
# 1  https://www.amazon.com/gp/customer-reviews/R19...            Ann
# 2  https://www.amazon.com/gp/customer-reviews/R18...         Bonnie
# 3  https://www.amazon.com/gp/customer-reviews/R36...      Ivan Gult
# 4  https://www.amazon.com/gp/customer-reviews/R2E...  Theodore Wild
#
# [5 rows x 21 columns]

# %%
print(df_reviews.shape)
print(df_reviews.columns)
# Out:
# (219785, 21)
# Index(['Unnamed: 0', 'retailerid', 'retailername', 'retailersku', 'upc',
#        'modelNumber', 'title', 'Brand', 'Category', 'SubCategory', 'weekid',
#        'WeekEnding', 'reviewDate', 'reviewId', 'reviewStars', 'isVerified',
#        'hasResponse', 'reviewText', 'reviewTitle', 'reviewsURL', 'reviewer'],
#       dtype='object')

# %%
df_reviews[['reviewText']]
# Out:
#                                                reviewText
# 0                                  Great Christmas gIft
# 1        Laundry. Easy to use. Convenience.Please keep...
# 2                                Love it. So easy to use
# 3        I was sick and had a friend recommend this to...
# 4                        Bags were weak and tore easily
# ...                                                   ...
# 219780   These are so easy to use. The water tastes gr...
# 219781  Like the price plus moisturizing and lip shade...
# 219782                                           Lovely.
# 219783  This facial cleanser is so awesome. My skin cl...
# 219784  I use Pine-Sol in my laundry! Gives a bit of a...
#
# [219785 rows x 1 columns]

# %%
df_reviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 219785 entries, 0 to 219784
# Data columns (total 21 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Unnamed: 0    219785 non-null  int64
#  1   retailerid    219785 non-null  int64
#  2   retailername  219785 non-null  object
#  3   retailersku   219785 non-null  object
#  4   upc           161475 non-null  object
#  5   modelNumber   199852 non-null  object
#  6   title         219785 non-null  object
#  7   Brand         219785 non-null  object
#  8   Category      219785 non-null  object
#  9   SubCategory   219785 non-null  object
#  10  weekid        219785 non-null  int64
#  11  WeekEnding    219785 non-null  object
#  12  reviewDate    219785 non-null  object
#  13  reviewId      219785 non-null  object
#  14  reviewStars   219785 non-null  float64
#  15  isVerified    219785 non-null  object
#  16  hasResponse   219785 non-null  object
#  17  reviewText    219600 non-null  object
#  18  reviewTitle   219756 non-null  object
#  19  reviewsURL    219785 non-null  object
#  20  reviewer      219772 non-null  object
# dtypes: float64(1), int64(3), object(17)
# memory usage: 35.2+ MB

# %%
df_reviews.describe(include=['O'])
# Out:
#        retailername retailersku            upc     modelNumber  \
# count        219785      219785         161475          199852
# unique            1        1654           1247            1478
# top      Amazon.com  B00FQT4LX2  12587785546.0  10012587785635
# freq         219785        4996           4953            4996
#
#                                                     title        Brand  \
# count                                              219785       219785
# unique                                               2788           20
# top     Glad ForceFlex Protection Series Tall Kitchen ...  Burt's Bees
# freq                                                 4192        52054
#
#                             Category SubCategory  WeekEnding  reviewDate  \
# count                         219785      219785      219785      219785
# unique                            62         151         213        1482
# top     Water Filtration & Softeners  Trash Bags  2020-01-04  2020-01-05
# freq                           43213       26413        2573         464
#
#               reviewId isVerified hasResponse reviewText      reviewTitle  \
# count           219785     219785      219785     219600           219756
# unique          212462          2           2     199837           136825
# top     R2L2VXGGNW0E27        yes          no      Good    Great product
# freq                 6     206281      212361        355             2045
#
#                                                reviewsURL         reviewer
# count                                              219785           219772
# unique                                             219692           135665
# top     https://www.amazon.com/gp/customer-reviews/R1L...  Amazon Customer
# freq                                                    3            15516

# %% [markdown]
# LETS CONSIDER ONLY BRITA FOR INITIAL UNDERSTANDING

# %%
df_Brita = df_reviews.loc[(df_reviews['weekid'] >= 201900)
                     & (df_reviews['weekid'] <= 202200) & (df_reviews['Brand']=="Brita")]

print(df_Brita.shape)
# Out:
# (41958, 21)

# %%
df_Brita['reviewText'].value_counts(normalize=True)
# Out:
# Good                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         0.001693
#  Good                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        0.001669
# Great                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        0.001359
#   Good                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       0.001288
#  Great product                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               0.001169
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ...
#  Nice filter. It is easy to fill and use. I place it inside my refrigerator for cold water and it fits nicely.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               0.000024
#  I can see why other customers say it has the potential for mold to grow and it’s hard to clean. I haven’t tried cleaning it yet but did notice a defect in the design. There’s a small opening at the top of the handle where water could collect. Overall it does seem easy to clean since the top portion comes out of the jug. Also I thought I read somewhere that it comes with a blue and white filer. I only received a white one. But I bought this for my plants so we will see if they complain.                                                                                                                                                                                  0.000024
#  What a delightful portable water vessel from world renowned Brita. Easy to use while providing great tasting water to consume. After filling the applicator and installing the required filter, you are ready for a gentle refreshing supply of water. Easy to use totally reusable and reliable.                                                                                                                                                                                                                                                                                                                                                                                           0.000024
#   My partner and I each have one of these bottles. We are very fond of them. One of our bottles has been in use for close to a year now, and it is still going strong. The filters are easy to change (we buy 3 packs here on Amazon) and last about 3 months each (I know it says two months... but we use the bottles primarily on Poland Spring water, which is already filtered, but I like the extra filtering. I will occasionally use tap water in my bottle, and the difference is quite noticeable between drinking it straight from the tap and drinking it from the filtered bottle.I like the size of the bottles and love the little strap on the top for carrying.5 stars      0.000024
#  These are so easy to use. The water tastes great and so far, we are very happy with the product.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            0.000024
# Name: reviewText, Length: 39559, dtype: float64

# %%
df_Brita['reviewText'] = df_Brita['reviewText'].astype('str')

df_Brita.describe(include=['O'])
# Out:
#        retailername retailersku            upc     modelNumber  \
# count         41958       41958          29211           41947
# unique            1         106             49             191
# top      Amazon.com  B015SY3VGM  60258360394.0  10060258363699
# freq          41958        4007           4007            3851
#
#                                                     title  Brand  \
# count                                               41958  41958
# unique                                                170      1
# top     Brita Standard UltraMax Water Filter Dispenser...  Brita
# freq                                                 3658  41958
#
#                             Category              SubCategory  WeekEnding  \
# count                          41958                    41958       41958
# unique                             3                        5         157
# top     Water Filtration & Softeners  Water Coolers & Filters  2020-01-11
# freq                           35407                    21430         502
#
#         reviewDate        reviewId isVerified hasResponse reviewText  \
# count        41958           41958      41958       41958      41958
# unique        1082           41830          2           2      39560
# top     2020-01-05  R1HQEZY7LPGS7B        yes          no      Good
# freq           105               3      39929       38915         71
#
#        reviewTitle                                         reviewsURL  \
# count        41957                                              41958
# unique       28997                                              41956
# top         Great   https://www.amazon.com/gp/customer-reviews/RRI...
# freq           327                                                  2
#
#                reviewer
# count             41956
# unique            30241
# top     Amazon Customer
# freq               3132

# %%
import gensim
from gensim.utils import simple_preprocess
from gensim.parsing.preprocessing import remove_stopwords
from nltk.stem import WordNetLemmatizer

# %%
df_Brita['P_Text'] = [remove_stopwords(line) for line in df_Brita['reviewText']]
df_Brita['P_Text'] = [simple_preprocess(line, deacc=True) for line in df_Brita['P_Text']]

# %%
print(df_Brita['P_Text'][0:10])
# Out:
# 6     [expecting, metal, looks, way, picture, verifi...
# 7     [love, product, finally, water, tastes, like, ...
# 11    [ordered, pack, one, worked, don, showing, red...
# 12                           [good, makes, water, hard]
# 31    [prior, purchasing, bottle, read, reviewers, h...
# 56    [for, people, posting, couldn, drink, it, that...
# 66    [very, easy, install, super, glad, different, ...
# 67    [we, hard, tap, water, tired, plants, looking,...
# 72    [tried, running, tap, water, filter, checking,...
# 76    [literally, struggle, time, need, open, close,...
# Name: P_Text, dtype: object
